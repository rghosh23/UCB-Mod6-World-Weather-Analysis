# %%
# 1a. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=10000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=10000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 2309

# %%
# 1b. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 2. Loop through the cities list.
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # 4. Build the city_url or endpoint for each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # 5. Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# 6. Make an API request for each city.
    try:
        # 7. Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_conditions = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Conditions": city_conditions})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | qaqortoq
# Processing Record 6 of Set 1 | burica
# City not found. Skipping...
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | belebey
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | galveston
# Processing Record 13 of Set 1 | paracin
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | bellefontaine
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | hobyo
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | takoradi
# Processing Record 27 of Set 1 | nytva
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | lufilufi
# Processing Record 30 of Set 1 | namatanai
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | pangai
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | fare
# Processing Record 35 of Set 1 | azare
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | angoche
# Processing Record 39 of Set 1 | pedernales
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | beloha
# Processing Record 43 of Set 1 | auki
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | bathsheba
# Processing Record 47 of Set 1 | souillac
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | wanning
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | havelock
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | cayenne
# Processing Record 5 of Set 2 | tilichiki
# Processing Record 6 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 2 | maisons-alfort
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | hobbs
# Processing Record 11 of Set 2 | misratah
# Processing Record 12 of Set 2 | acajutla
# Processing Record 13 of Set 2 | nioro
# Processing Record 14 of Set 2 | riberalta
# Processing Record 15 of Set 2 | luchow
# Processing Record 16 of Set 2 | winslow
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | codrington
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | yulara
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | noumea
# Processing Record 23 of Set 2 | yumen
# Processing Record 24 of Set 2 | nioki
# Processing Record 25 of Set 2 | nuevo casas grandes
# Processing Record 26 of Set 2 | lichinga
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | novo oriente
# Processing Record 29 of Set 2 | porbandar
# Processing Record 30 of Set 2 | ahipara
# Processing Record 31 of Set 2 | fortuna
# Processing Record 32 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 2 | broome
# Processing Record 34 of Set 2 | odweyne
# Processing Record 35 of Set 2 | kharan
# Processing Record 36 of Set 2 | harrison
# Processing Record 37 of Set 2 | labuhan
# Processing Record 38 of Set 2 | kinchil
# Processing Record 39 of Set 2 | lahij
# Processing Record 40 of Set 2 | borazjan
# Processing Record 41 of Set 2 | buta
# Processing Record 42 of Set 2 | portland
# Processing Record 43 of Set 2 | alekseyevka
# Processing Record 44 of Set 2 | vila velha
# Processing Record 45 of Set 2 | kamenka
# Processing Record 46 of Set 2 | yar-sale
# Processing Record 47 of Set 2 | marsaxlokk
# Processing Record 48 of Set 2 | dongying
# Processing Record 49 of Set 2 | saint-pierre
# Processing Record 50 of Set 2 | kismayo
# Processing Record 1 of Set 3 | camacha
# Processing Record 2 of Set 3 | constitucion
# Processing Record 3 of Set 3 | erie
# Processing Record 4 of Set 3 | gondanglegi
# Processing Record 5 of Set 3 | copala
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | mahibadhoo
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | guerrero negro
# Processing Record 12 of Set 3 | natal
# Processing Record 13 of Set 3 | naron
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | ambilobe
# Processing Record 16 of Set 3 | rochester
# Processing Record 17 of Set 3 | klaksvik
# Processing Record 18 of Set 3 | kahului
# Processing Record 19 of Set 3 | nome
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | tagana-an
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | el dovio
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | vadso
# Processing Record 28 of Set 3 | mehamn
# Processing Record 29 of Set 3 | baker city
# Processing Record 30 of Set 3 | bumba
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | la ronge
# Processing Record 34 of Set 3 | anadyr
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | dhidhdhoo
# Processing Record 37 of Set 3 | hay river
# Processing Record 38 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 39 of Set 3 | havre
# Processing Record 40 of Set 3 | whyalla
# Processing Record 41 of Set 3 | roma
# Processing Record 42 of Set 3 | kapaa
# Processing Record 43 of Set 3 | san cristobal
# Processing Record 44 of Set 3 | shache
# Processing Record 45 of Set 3 | san jose
# Processing Record 46 of Set 3 | simao
# Processing Record 47 of Set 3 | gannan
# Processing Record 48 of Set 3 | faanui
# Processing Record 49 of Set 3 | santa catarina de tepehuanes
# Processing Record 50 of Set 3 | salalah
# Processing Record 1 of Set 4 | bowen
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | kyabe
# Processing Record 4 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 5 of Set 4 | merauke
# Processing Record 6 of Set 4 | padang
# Processing Record 7 of Set 4 | gigmoto
# Processing Record 8 of Set 4 | san luis
# Processing Record 9 of Set 4 | bluff
# Processing Record 10 of Set 4 | lata
# Processing Record 11 of Set 4 | miandrivazo
# Processing Record 12 of Set 4 | coelho neto
# Processing Record 13 of Set 4 | mortka
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | aire-sur-la-lys
# Processing Record 16 of Set 4 | cabo san lucas
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | amapa
# Processing Record 19 of Set 4 | ulaangom
# Processing Record 20 of Set 4 | nong kung si
# Processing Record 21 of Set 4 | zalantun
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | darnah
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | yaan
# Processing Record 26 of Set 4 | sterling
# Processing Record 27 of Set 4 | coos bay
# Processing Record 28 of Set 4 | khislavichi
# Processing Record 29 of Set 4 | vardo
# Processing Record 30 of Set 4 | hakui
# Processing Record 31 of Set 4 | zyryanka
# Processing Record 32 of Set 4 | onega
# Processing Record 33 of Set 4 | te anau
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | kamen-na-obi
# Processing Record 38 of Set 4 | jamestown
# Processing Record 39 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 4 | murray bridge
# Processing Record 41 of Set 4 | dingle
# Processing Record 42 of Set 4 | torbay
# Processing Record 43 of Set 4 | bubaque
# Processing Record 44 of Set 4 | san jeronimo
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | burnie
# Processing Record 47 of Set 4 | denpasar
# Processing Record 48 of Set 4 | port-cartier
# Processing Record 49 of Set 4 | college
# Processing Record 50 of Set 4 | namibe
# Processing Record 1 of Set 5 | nouadhibou
# Processing Record 2 of Set 5 | olafsvik
# Processing Record 3 of Set 5 | kavieng
# Processing Record 4 of Set 5 | hithadhoo
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | sandpoint
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | cananeia
# Processing Record 9 of Set 5 | bethel
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | warri
# Processing Record 12 of Set 5 | kalispell
# Processing Record 13 of Set 5 | odessa
# Processing Record 14 of Set 5 | meiktila
# Processing Record 15 of Set 5 | aklavik
# Processing Record 16 of Set 5 | argelia
# Processing Record 17 of Set 5 | wawa
# Processing Record 18 of Set 5 | lagoa
# Processing Record 19 of Set 5 | tiksi
# Processing Record 20 of Set 5 | verkhnevilyuysk
# Processing Record 21 of Set 5 | yerbogachen
# Processing Record 22 of Set 5 | coihaique
# Processing Record 23 of Set 5 | mbini
# Processing Record 24 of Set 5 | bahia honda
# Processing Record 25 of Set 5 | new norfolk
# Processing Record 26 of Set 5 | tantoyuca
# Processing Record 27 of Set 5 | quatre cocos
# Processing Record 28 of Set 5 | maragogi
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | primorsk
# Processing Record 31 of Set 5 | mutoko
# Processing Record 32 of Set 5 | pizarro
# Processing Record 33 of Set 5 | bonavista
# Processing Record 34 of Set 5 | pridonskoy
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | pombas
# Processing Record 37 of Set 5 | baykit
# Processing Record 38 of Set 5 | ambon
# Processing Record 39 of Set 5 | entre rios
# Processing Record 40 of Set 5 | zemio
# Processing Record 41 of Set 5 | santa maria
# Processing Record 42 of Set 5 | bafq
# Processing Record 43 of Set 5 | abhar
# Processing Record 44 of Set 5 | magadan
# Processing Record 45 of Set 5 | mareeba
# Processing Record 46 of Set 5 | miraflores
# Processing Record 47 of Set 5 | sarangani
# Processing Record 48 of Set 5 | nemuro
# Processing Record 49 of Set 5 | teguise
# Processing Record 50 of Set 5 | stykkisholmur
# Processing Record 1 of Set 6 | tacuarembo
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | muros
# Processing Record 4 of Set 6 | el tambo
# Processing Record 5 of Set 6 | abasolo
# Processing Record 6 of Set 6 | apaseo el alto
# Processing Record 7 of Set 6 | naze
# Processing Record 8 of Set 6 | kaitangata
# Processing Record 9 of Set 6 | ulladulla
# Processing Record 10 of Set 6 | alberton
# Processing Record 11 of Set 6 | lamu
# Processing Record 12 of Set 6 | saint anthony
# Processing Record 13 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 14 of Set 6 | lompoc
# Processing Record 15 of Set 6 | tonj
# Processing Record 16 of Set 6 | kemise
# Processing Record 17 of Set 6 | talavera de la reina
# Processing Record 18 of Set 6 | taunggyi
# Processing Record 19 of Set 6 | dwarka
# Processing Record 20 of Set 6 | hami
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | chickasha
# Processing Record 23 of Set 6 | carauari
# Processing Record 24 of Set 6 | tarabuco
# Processing Record 25 of Set 6 | motygino
# Processing Record 26 of Set 6 | san felipe
# Processing Record 27 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 6 | talwandi bhai
# Processing Record 29 of Set 6 | nelson bay
# Processing Record 30 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 6 | naples
# Processing Record 32 of Set 6 | patiya
# Processing Record 33 of Set 6 | kiruna
# Processing Record 34 of Set 6 | half moon bay
# Processing Record 35 of Set 6 | hofn
# Processing Record 36 of Set 6 | san pedro
# Processing Record 37 of Set 6 | porto novo
# Processing Record 38 of Set 6 | sept-iles
# Processing Record 39 of Set 6 | khudumelapye
# Processing Record 40 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 6 | port-gentil
# Processing Record 42 of Set 6 | mount isa
# Processing Record 43 of Set 6 | tarakan
# Processing Record 44 of Set 6 | praia
# Processing Record 45 of Set 6 | dharmadam
# Processing Record 46 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 6 | walvis bay
# Processing Record 48 of Set 6 | timra
# Processing Record 49 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | poum
# Processing Record 1 of Set 7 | tuatapere
# Processing Record 2 of Set 7 | puerto suarez
# Processing Record 3 of Set 7 | vedea
# Processing Record 4 of Set 7 | ponta do sol
# Processing Record 5 of Set 7 | christchurch
# Processing Record 6 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 7 | russell
# Processing Record 8 of Set 7 | redmond
# Processing Record 9 of Set 7 | itaituba
# Processing Record 10 of Set 7 | neuquen
# Processing Record 11 of Set 7 | georgetown
# Processing Record 12 of Set 7 | nanakuli
# Processing Record 13 of Set 7 | matara
# Processing Record 14 of Set 7 | rocha
# Processing Record 15 of Set 7 | haines junction
# Processing Record 16 of Set 7 | itarema
# Processing Record 17 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 7 | marawi
# Processing Record 19 of Set 7 | languyan
# Processing Record 20 of Set 7 | salekhard
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | monrovia
# Processing Record 23 of Set 7 | ryotsu
# Processing Record 24 of Set 7 | dimbokro
# Processing Record 25 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 7 | sao geraldo do araguaia
# Processing Record 27 of Set 7 | varadero
# Processing Record 28 of Set 7 | vilyuysk
# Processing Record 29 of Set 7 | lishui
# Processing Record 30 of Set 7 | nuuk
# Processing Record 31 of Set 7 | lagos
# Processing Record 32 of Set 7 | batemans bay
# Processing Record 33 of Set 7 | rawson
# Processing Record 34 of Set 7 | esperance
# Processing Record 35 of Set 7 | bahar
# Processing Record 36 of Set 7 | margate
# Processing Record 37 of Set 7 | hambantota
# Processing Record 38 of Set 7 | vestmannaeyjar
# Processing Record 39 of Set 7 | sinnamary
# Processing Record 40 of Set 7 | toyooka
# Processing Record 41 of Set 7 | berani
# Processing Record 42 of Set 7 | villavicencio
# Processing Record 43 of Set 7 | maniitsoq
# Processing Record 44 of Set 7 | shenzhen
# Processing Record 45 of Set 7 | garowe
# Processing Record 46 of Set 7 | mount gambier
# Processing Record 47 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 7 | dulag
# Processing Record 49 of Set 7 | fairview
# Processing Record 50 of Set 7 | antofagasta
# Processing Record 1 of Set 8 | sibinal
# Processing Record 2 of Set 8 | saint-joseph
# Processing Record 3 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 8 | awjilah
# Processing Record 6 of Set 8 | yining
# Processing Record 7 of Set 8 | pidhorodne
# Processing Record 8 of Set 8 | rafai
# Processing Record 9 of Set 8 | ilmenau
# Processing Record 10 of Set 8 | berbera
# Processing Record 11 of Set 8 | kantang
# Processing Record 12 of Set 8 | iqaluit
# Processing Record 13 of Set 8 | athabasca
# Processing Record 14 of Set 8 | mackay
# Processing Record 15 of Set 8 | kununurra
# Processing Record 16 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 8 | yichang
# Processing Record 19 of Set 8 | tarnogskiy gorodok
# Processing Record 20 of Set 8 | gondar
# Processing Record 21 of Set 8 | parasia
# Processing Record 22 of Set 8 | nanortalik
# Processing Record 23 of Set 8 | songjianghe
# Processing Record 24 of Set 8 | marienburg
# Processing Record 25 of Set 8 | alimanguan
# City not found. Skipping...
# Processing Record 26 of Set 8 | chiredzi
# Processing Record 27 of Set 8 | cascais
# Processing Record 28 of Set 8 | mayumba
# Processing Record 29 of Set 8 | los llanos de aridane
# Processing Record 30 of Set 8 | kupang
# Processing Record 31 of Set 8 | ballina
# Processing Record 32 of Set 8 | kiunga
# Processing Record 33 of Set 8 | grand-santi
# Processing Record 34 of Set 8 | abu samrah
# Processing Record 35 of Set 8 | washington
# Processing Record 36 of Set 8 | cidreira
# Processing Record 37 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 8 | guilin
# Processing Record 39 of Set 8 | trujillo
# Processing Record 40 of Set 8 | sorland
# Processing Record 41 of Set 8 | show low
# Processing Record 42 of Set 8 | chapais
# Processing Record 43 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 8 | salym
# Processing Record 46 of Set 8 | voyskovitsy
# Processing Record 47 of Set 8 | bilma
# Processing Record 48 of Set 8 | hamilton
# Processing Record 49 of Set 8 | clyde river
# Processing Record 50 of Set 8 | paraiba do sul
# Processing Record 1 of Set 9 | bambous virieux
# Processing Record 2 of Set 9 | pangody
# Processing Record 3 of Set 9 | lulea
# Processing Record 4 of Set 9 | osterburg
# Processing Record 5 of Set 9 | yangambi
# Processing Record 6 of Set 9 | gramoteino
# Processing Record 7 of Set 9 | meadow lake
# Processing Record 8 of Set 9 | sanandaj
# Processing Record 9 of Set 9 | wajima
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | katsuura
# Processing Record 12 of Set 9 | ossora
# Processing Record 13 of Set 9 | harper
# Processing Record 14 of Set 9 | sitka
# Processing Record 15 of Set 9 | zhuji
# Processing Record 16 of Set 9 | tevriz
# Processing Record 17 of Set 9 | quartucciu
# Processing Record 18 of Set 9 | shenjiamen
# Processing Record 19 of Set 9 | svetlogorsk
# Processing Record 20 of Set 9 | kloulklubed
# Processing Record 21 of Set 9 | panaba
# Processing Record 22 of Set 9 | tieli
# Processing Record 23 of Set 9 | furano
# Processing Record 24 of Set 9 | progreso
# Processing Record 25 of Set 9 | antonovo
# Processing Record 26 of Set 9 | botou
# Processing Record 27 of Set 9 | chastoozerye
# City not found. Skipping...
# Processing Record 28 of Set 9 | heishan
# Processing Record 29 of Set 9 | gualeguay
# Processing Record 30 of Set 9 | ilulissat
# Processing Record 31 of Set 9 | beringovskiy
# Processing Record 32 of Set 9 | ancud
# Processing Record 33 of Set 9 | fort nelson
# Processing Record 34 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 9 | cherskiy
# Processing Record 36 of Set 9 | katherine
# Processing Record 37 of Set 9 | rio gallegos
# Processing Record 38 of Set 9 | grand gaube
# Processing Record 39 of Set 9 | banda aceh
# Processing Record 40 of Set 9 | dois vizinhos
# Processing Record 41 of Set 9 | vanimo
# Processing Record 42 of Set 9 | necochea
# Processing Record 43 of Set 9 | bjornevatn
# Processing Record 44 of Set 9 | kropotkin
# Processing Record 45 of Set 9 | durant
# Processing Record 46 of Set 9 | uren
# Processing Record 47 of Set 9 | aban
# Processing Record 48 of Set 9 | sola
# Processing Record 49 of Set 9 | hoi an
# Processing Record 50 of Set 9 | catamarca
# Processing Record 1 of Set 10 | ferme-neuve
# Processing Record 2 of Set 10 | sao joao da barra
# Processing Record 3 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 10 | umm lajj
# Processing Record 5 of Set 10 | san vicente
# Processing Record 6 of Set 10 | errol
# Processing Record 7 of Set 10 | komsomolskiy
# Processing Record 8 of Set 10 | oranjestad
# Processing Record 9 of Set 10 | daru
# Processing Record 10 of Set 10 | toora-khem
# Processing Record 11 of Set 10 | saskylakh
# Processing Record 12 of Set 10 | xinzhou
# Processing Record 13 of Set 10 | oranjemund
# Processing Record 14 of Set 10 | moose factory
# Processing Record 15 of Set 10 | lianran
# Processing Record 16 of Set 10 | mubi
# Processing Record 17 of Set 10 | oum hadjer
# Processing Record 18 of Set 10 | san andres
# Processing Record 19 of Set 10 | pangnirtung
# Processing Record 20 of Set 10 | monforte de lemos
# Processing Record 21 of Set 10 | vostok
# Processing Record 22 of Set 10 | tarko-sale
# Processing Record 23 of Set 10 | axim
# Processing Record 24 of Set 10 | rath
# Processing Record 25 of Set 10 | coruripe
# Processing Record 26 of Set 10 | bogdanci
# Processing Record 27 of Set 10 | acapulco
# Processing Record 28 of Set 10 | grindavik
# Processing Record 29 of Set 10 | bosaso
# Processing Record 30 of Set 10 | pacific grove
# Processing Record 31 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 10 | abha
# Processing Record 33 of Set 10 | grong
# Processing Record 34 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 10 | krasnyy chikoy
# Processing Record 36 of Set 10 | borzna
# Processing Record 37 of Set 10 | isla vista
# Processing Record 38 of Set 10 | lavrentiya
# Processing Record 39 of Set 10 | bandarbeyla
# Processing Record 40 of Set 10 | elizabeth city
# Processing Record 41 of Set 10 | aykhal
# Processing Record 42 of Set 10 | san policarpo
# Processing Record 43 of Set 10 | rock sound
# Processing Record 44 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 45 of Set 10 | port pirie
# Processing Record 46 of Set 10 | buchanan
# Processing Record 47 of Set 10 | ketchikan
# Processing Record 48 of Set 10 | faya
# Processing Record 49 of Set 10 | siocon
# Processing Record 50 of Set 10 | saint-georges
# Processing Record 1 of Set 11 | emerald
# Processing Record 2 of Set 11 | conde
# Processing Record 3 of Set 11 | sembe
# Processing Record 4 of Set 11 | kruisfontein
# Processing Record 5 of Set 11 | owo
# Processing Record 6 of Set 11 | goundam
# Processing Record 7 of Set 11 | mayo
# Processing Record 8 of Set 11 | andselv
# City not found. Skipping...
# Processing Record 9 of Set 11 | port keats
# Processing Record 10 of Set 11 | la orotava
# Processing Record 11 of Set 11 | whitehorse
# Processing Record 12 of Set 11 | ust-nera
# Processing Record 13 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 11 | nalgonda
# Processing Record 15 of Set 11 | beberibe
# Processing Record 16 of Set 11 | porto velho
# Processing Record 17 of Set 11 | pahrump
# Processing Record 18 of Set 11 | dayong
# Processing Record 19 of Set 11 | jieshi
# Processing Record 20 of Set 11 | lasa
# Processing Record 21 of Set 11 | moron
# Processing Record 22 of Set 11 | awbari
# Processing Record 23 of Set 11 | cozumel
# Processing Record 24 of Set 11 | mahon
# Processing Record 25 of Set 11 | troitsko-pechorsk
# Processing Record 26 of Set 11 | ambovombe
# Processing Record 27 of Set 11 | tamandare
# Processing Record 28 of Set 11 | impfondo
# Processing Record 29 of Set 11 | pierre
# Processing Record 30 of Set 11 | asfi
# Processing Record 31 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 11 | mikhaylovka
# Processing Record 33 of Set 11 | partur
# Processing Record 34 of Set 11 | adrar
# Processing Record 35 of Set 11 | sangar
# Processing Record 36 of Set 11 | havoysund
# Processing Record 37 of Set 11 | vila
# Processing Record 38 of Set 11 | matay
# Processing Record 39 of Set 11 | lastoursville
# Processing Record 40 of Set 11 | haimen
# Processing Record 41 of Set 11 | ardakan
# Processing Record 42 of Set 11 | guaymas
# Processing Record 43 of Set 11 | kingman
# Processing Record 44 of Set 11 | watrous
# Processing Record 45 of Set 11 | peniche
# Processing Record 46 of Set 11 | wanaka
# Processing Record 47 of Set 11 | provideniya
# Processing Record 48 of Set 11 | karasburg
# Processing Record 49 of Set 11 | dangriga
# Processing Record 50 of Set 11 | sur
# Processing Record 1 of Set 12 | kirakira
# Processing Record 2 of Set 12 | adre
# Processing Record 3 of Set 12 | santa cruz
# Processing Record 4 of Set 12 | naryan-mar
# Processing Record 5 of Set 12 | marrakesh
# Processing Record 6 of Set 12 | avera
# Processing Record 7 of Set 12 | carutapera
# Processing Record 8 of Set 12 | kumher
# Processing Record 9 of Set 12 | nampa
# Processing Record 10 of Set 12 | sosnovoborsk
# Processing Record 11 of Set 12 | maceio
# Processing Record 12 of Set 12 | pereira barreto
# Processing Record 13 of Set 12 | areosa
# Processing Record 14 of Set 12 | ngunguru
# Processing Record 15 of Set 12 | jinchang
# Processing Record 16 of Set 12 | saint-francois
# Processing Record 17 of Set 12 | port arthur
# Processing Record 18 of Set 12 | westport
# Processing Record 19 of Set 12 | casas grandes
# Processing Record 20 of Set 12 | villa guerrero
# Processing Record 21 of Set 12 | buraydah
# Processing Record 22 of Set 12 | srednekolymsk
# Processing Record 23 of Set 12 | malakal
# Processing Record 24 of Set 12 | giddarbaha
# Processing Record 25 of Set 12 | bystrice nad pernstejnem
# Processing Record 26 of Set 12 | hunsur
# Processing Record 27 of Set 12 | mezen
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | kargil
# Processing Record 30 of Set 12 | vitim
# Processing Record 31 of Set 12 | mahbubnagar
# Processing Record 32 of Set 12 | tahe
# Processing Record 33 of Set 12 | vidim
# Processing Record 34 of Set 12 | tambovka
# Processing Record 35 of Set 12 | gat
# Processing Record 36 of Set 12 | surgana
# Processing Record 37 of Set 12 | luderitz
# Processing Record 38 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 12 | nabire
# Processing Record 40 of Set 12 | dharchula
# Processing Record 41 of Set 12 | kondinskoye
# Processing Record 42 of Set 12 | bilibino
# Processing Record 43 of Set 12 | sanlucar de barrameda
# Processing Record 44 of Set 12 | makakilo city
# Processing Record 45 of Set 12 | kedougou
# Processing Record 46 of Set 12 | balabac
# Processing Record 47 of Set 12 | kushiro
# Processing Record 48 of Set 12 | luba
# Processing Record 49 of Set 12 | kumluca
# Processing Record 50 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 13 | broken hill
# Processing Record 2 of Set 13 | juegang
# Processing Record 3 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 13 | verkhoyansk
# Processing Record 5 of Set 13 | dubbo
# Processing Record 6 of Set 13 | miles city
# Processing Record 7 of Set 13 | flinders
# Processing Record 8 of Set 13 | suba
# Processing Record 9 of Set 13 | kaniama
# Processing Record 10 of Set 13 | inhambupe
# Processing Record 11 of Set 13 | shingu
# Processing Record 12 of Set 13 | hovd
# Processing Record 13 of Set 13 | waddan
# Processing Record 14 of Set 13 | allanridge
# Processing Record 15 of Set 13 | tessalit
# Processing Record 16 of Set 13 | morgan city
# Processing Record 17 of Set 13 | palmer
# Processing Record 18 of Set 13 | yuksekova
# Processing Record 19 of Set 13 | vao
# Processing Record 20 of Set 13 | sorong
# Processing Record 21 of Set 13 | egvekinot
# Processing Record 22 of Set 13 | siverskiy
# Processing Record 23 of Set 13 | ceyhan
# Processing Record 24 of Set 13 | el carmen
# Processing Record 25 of Set 13 | metehara
# City not found. Skipping...
# Processing Record 26 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 13 | yagodnoye
# Processing Record 28 of Set 13 | weinan
# Processing Record 29 of Set 13 | letka
# Processing Record 30 of Set 13 | fatezh
# Processing Record 31 of Set 13 | kayerkan
# Processing Record 32 of Set 13 | binghamton
# Processing Record 33 of Set 13 | sao jose da coroa grande
# Processing Record 34 of Set 13 | saldanha
# Processing Record 35 of Set 13 | altay
# Processing Record 36 of Set 13 | kasangulu
# Processing Record 37 of Set 13 | kyra
# Processing Record 38 of Set 13 | bobo dioulasso
# Processing Record 39 of Set 13 | jennings
# Processing Record 40 of Set 13 | tambopata
# Processing Record 41 of Set 13 | tecoanapa
# Processing Record 42 of Set 13 | medina del campo
# Processing Record 43 of Set 13 | nizwa
# Processing Record 44 of Set 13 | pisco
# Processing Record 45 of Set 13 | tucumcari
# Processing Record 46 of Set 13 | caravelas
# Processing Record 47 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 48 of Set 13 | castanhal
# Processing Record 49 of Set 13 | puerto ayacucho
# Processing Record 50 of Set 13 | aktash
# Processing Record 1 of Set 14 | roald
# Processing Record 2 of Set 14 | maldonado
# Processing Record 3 of Set 14 | kindu
# Processing Record 4 of Set 14 | chor
# Processing Record 5 of Set 14 | urengoy
# Processing Record 6 of Set 14 | concordia
# Processing Record 7 of Set 14 | huautla
# Processing Record 8 of Set 14 | dera bugti
# Processing Record 9 of Set 14 | nsanje
# Processing Record 10 of Set 14 | kavaratti
# Processing Record 11 of Set 14 | alice springs
# Processing Record 12 of Set 14 | blagaj
# Processing Record 13 of Set 14 | honningsvag
# Processing Record 14 of Set 14 | viedma
# Processing Record 15 of Set 14 | ampanihy
# Processing Record 16 of Set 14 | manono
# Processing Record 17 of Set 14 | trairi
# Processing Record 18 of Set 14 | bull savanna
# Processing Record 19 of Set 14 | svetlyy
# Processing Record 20 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 21 of Set 14 | vikulovo
# Processing Record 22 of Set 14 | pacifica
# Processing Record 23 of Set 14 | capitan bado
# Processing Record 24 of Set 14 | novyy urengoy
# Processing Record 25 of Set 14 | skjervoy
# Processing Record 26 of Set 14 | peruibe
# Processing Record 27 of Set 14 | zeya
# Processing Record 28 of Set 14 | londoko
# Processing Record 29 of Set 14 | novyy urgal
# Processing Record 30 of Set 14 | morehead
# Processing Record 31 of Set 14 | mamallapuram
# Processing Record 32 of Set 14 | aksarka
# Processing Record 33 of Set 14 | san carlos de bariloche
# Processing Record 34 of Set 14 | bisira
# Processing Record 35 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 14 | goya
# Processing Record 37 of Set 14 | high level
# Processing Record 38 of Set 14 | menongue
# Processing Record 39 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 14 | sioux lookout
# Processing Record 41 of Set 14 | dobroye
# Processing Record 42 of Set 14 | lazaro cardenas
# Processing Record 43 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 14 | rovaniemi
# Processing Record 45 of Set 14 | dzilam gonzalez
# Processing Record 46 of Set 14 | vila franca do campo
# Processing Record 47 of Set 14 | krasnoselkup
# Processing Record 48 of Set 14 | springdale
# Processing Record 49 of Set 14 | samarai
# Processing Record 50 of Set 14 | marinette
# Processing Record 1 of Set 15 | quirinopolis
# Processing Record 2 of Set 15 | shihezi
# Processing Record 3 of Set 15 | eskisehir
# Processing Record 4 of Set 15 | talcahuano
# Processing Record 5 of Set 15 | ventspils
# Processing Record 6 of Set 15 | akyab
# Processing Record 7 of Set 15 | dungarpur
# Processing Record 8 of Set 15 | okhotsk
# Processing Record 9 of Set 15 | sheridan
# Processing Record 10 of Set 15 | mao
# Processing Record 11 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 12 of Set 15 | colon
# Processing Record 13 of Set 15 | nanhai
# Processing Record 14 of Set 15 | kusk
# City not found. Skipping...
# Processing Record 15 of Set 15 | aguimes
# Processing Record 16 of Set 15 | baikunthpur
# Processing Record 17 of Set 15 | launceston
# Processing Record 18 of Set 15 | karachi
# Processing Record 19 of Set 15 | bourail
# Processing Record 20 of Set 15 | leshukonskoye
# Processing Record 21 of Set 15 | aleksandrow kujawski
# Processing Record 22 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 23 of Set 15 | kutum
# Processing Record 24 of Set 15 | punta alta
# Processing Record 25 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 15 | takahagi
# Processing Record 27 of Set 15 | kinkala
# Processing Record 28 of Set 15 | sumenep
# Processing Record 29 of Set 15 | haapu
# City not found. Skipping...
# Processing Record 30 of Set 15 | antalaha
# Processing Record 31 of Set 15 | gravdal
# Processing Record 32 of Set 15 | beira
# Processing Record 33 of Set 15 | rive-de-gier
# Processing Record 34 of Set 15 | tulu bolo
# Processing Record 35 of Set 15 | khandyga
# Processing Record 36 of Set 15 | palauig
# Processing Record 37 of Set 15 | angra
# City not found. Skipping...
# Processing Record 38 of Set 15 | sao borja
# Processing Record 39 of Set 15 | flin flon
# Processing Record 40 of Set 15 | sao luis
# Processing Record 41 of Set 15 | boende
# Processing Record 42 of Set 15 | beterou
# Processing Record 43 of Set 15 | bara
# Processing Record 44 of Set 15 | imbituba
# Processing Record 45 of Set 15 | riviere-au-renard
# Processing Record 46 of Set 15 | seoul
# Processing Record 47 of Set 15 | sulangan
# Processing Record 48 of Set 15 | tambulan
# City not found. Skipping...
# Processing Record 49 of Set 15 | kemijarvi
# Processing Record 50 of Set 15 | yataity
# Processing Record 1 of Set 16 | vanavara
# Processing Record 2 of Set 16 | tual
# Processing Record 3 of Set 16 | masvingo
# Processing Record 4 of Set 16 | escanaba
# Processing Record 5 of Set 16 | dibaya
# City not found. Skipping...
# Processing Record 6 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 16 | lodja
# Processing Record 8 of Set 16 | sydney
# Processing Record 9 of Set 16 | sosnogorsk
# Processing Record 10 of Set 16 | balakhta
# Processing Record 11 of Set 16 | riyadh
# Processing Record 12 of Set 16 | sinjah
# City not found. Skipping...
# Processing Record 13 of Set 16 | lincoln
# Processing Record 14 of Set 16 | yeroham
# Processing Record 15 of Set 16 | bullas
# Processing Record 16 of Set 16 | mayor pablo lagerenza
# Processing Record 17 of Set 16 | hersbruck
# Processing Record 18 of Set 16 | cockburn town
# Processing Record 19 of Set 16 | cap malheureux
# Processing Record 20 of Set 16 | fushan
# Processing Record 21 of Set 16 | santa paula
# Processing Record 22 of Set 16 | karratha
# Processing Record 23 of Set 16 | plettenberg bay
# Processing Record 24 of Set 16 | ksenyevka
# City not found. Skipping...
# Processing Record 25 of Set 16 | benguela
# Processing Record 26 of Set 16 | kuytun
# Processing Record 27 of Set 16 | bandipur
# Processing Record 28 of Set 16 | marica
# Processing Record 29 of Set 16 | nivala
# Processing Record 30 of Set 16 | riachao
# Processing Record 31 of Set 16 | west bay
# Processing Record 32 of Set 16 | kodinsk
# Processing Record 33 of Set 16 | kieta
# Processing Record 34 of Set 16 | kaeo
# Processing Record 35 of Set 16 | mecca
# Processing Record 36 of Set 16 | brae
# Processing Record 37 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 16 | bonthe
# Processing Record 39 of Set 16 | keetmanshoop
# Processing Record 40 of Set 16 | barra do garcas
# Processing Record 41 of Set 16 | grand forks
# Processing Record 42 of Set 16 | djambala
# Processing Record 43 of Set 16 | atherton
# Processing Record 44 of Set 16 | le passage
# Processing Record 45 of Set 16 | dunedin
# Processing Record 46 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 16 | sinop
# Processing Record 48 of Set 16 | mwinilunga
# Processing Record 49 of Set 16 | luganville
# Processing Record 50 of Set 16 | kommunar
# Processing Record 1 of Set 17 | westminster
# Processing Record 2 of Set 17 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 17 | leningradskiy
# Processing Record 4 of Set 17 | kariba
# Processing Record 5 of Set 17 | krasnogorskoye
# Processing Record 6 of Set 17 | totness
# Processing Record 7 of Set 17 | danielskuil
# Processing Record 8 of Set 17 | nardaran
# Processing Record 9 of Set 17 | kingston upon hull
# Processing Record 10 of Set 17 | lillooet
# Processing Record 11 of Set 17 | lamar
# Processing Record 12 of Set 17 | pardina
# Processing Record 13 of Set 17 | oussouye
# Processing Record 14 of Set 17 | macaparana
# Processing Record 15 of Set 17 | kadhan
# Processing Record 16 of Set 17 | pinsk
# Processing Record 17 of Set 17 | baoro
# Processing Record 18 of Set 17 | poronaysk
# Processing Record 19 of Set 17 | dasoguz
# Processing Record 20 of Set 17 | villa bruzual
# Processing Record 21 of Set 17 | huangnihe
# Processing Record 22 of Set 17 | gwadar
# Processing Record 23 of Set 17 | vysha
# Processing Record 24 of Set 17 | saint-augustin
# Processing Record 25 of Set 17 | santa isabel do rio negro
# Processing Record 26 of Set 17 | bristol
# Processing Record 27 of Set 17 | wenchi
# Processing Record 28 of Set 17 | umba
# Processing Record 29 of Set 17 | cambuquira
# Processing Record 30 of Set 17 | mazara del vallo
# Processing Record 31 of Set 17 | unye
# City not found. Skipping...
# Processing Record 32 of Set 17 | japura
# Processing Record 33 of Set 17 | biryusinsk
# Processing Record 34 of Set 17 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 17 | taiobeiras
# Processing Record 36 of Set 17 | isetskoye
# Processing Record 37 of Set 17 | port hardy
# Processing Record 38 of Set 17 | lima
# Processing Record 39 of Set 17 | krutikha
# Processing Record 40 of Set 17 | magistralnyy
# Processing Record 41 of Set 17 | sisimiut
# Processing Record 42 of Set 17 | mahadday weyne
# City not found. Skipping...
# Processing Record 43 of Set 17 | puerto escondido
# Processing Record 44 of Set 17 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 17 | tura
# Processing Record 46 of Set 17 | concepcion
# Processing Record 47 of Set 17 | kimbe
# Processing Record 48 of Set 17 | choucheng
# City not found. Skipping...
# Processing Record 49 of Set 17 | urucara
# Processing Record 50 of Set 17 | prince rupert
# Processing Record 1 of Set 18 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 18 | tacuati
# Processing Record 3 of Set 18 | asau
# Processing Record 4 of Set 18 | rostaq
# City not found. Skipping...
# Processing Record 5 of Set 18 | bud
# Processing Record 6 of Set 18 | kupino
# Processing Record 7 of Set 18 | crixas
# Processing Record 8 of Set 18 | dakar
# Processing Record 9 of Set 18 | novonikolsk
# Processing Record 10 of Set 18 | erba
# Processing Record 11 of Set 18 | simpang
# Processing Record 12 of Set 18 | waipawa
# Processing Record 13 of Set 18 | lebork
# Processing Record 14 of Set 18 | brewster
# Processing Record 15 of Set 18 | jiaozhou
# Processing Record 16 of Set 18 | grado
# Processing Record 17 of Set 18 | mandiana
# Processing Record 18 of Set 18 | olavarria
# Processing Record 19 of Set 18 | beyneu
# Processing Record 20 of Set 18 | berlevag
# Processing Record 21 of Set 18 | siilinjarvi
# Processing Record 22 of Set 18 | dujuma
# City not found. Skipping...
# Processing Record 23 of Set 18 | liverpool
# Processing Record 24 of Set 18 | vaitape
# Processing Record 25 of Set 18 | weyburn
# Processing Record 26 of Set 18 | amalapuram
# Processing Record 27 of Set 18 | ostrowiec swietokrzyski
# Processing Record 28 of Set 18 | khonsa
# Processing Record 29 of Set 18 | sohag
# Processing Record 30 of Set 18 | mucurapo
# Processing Record 31 of Set 18 | alihe
# Processing Record 32 of Set 18 | shelburne
# Processing Record 33 of Set 18 | deputatskiy
# Processing Record 34 of Set 18 | polunochnoye
# Processing Record 35 of Set 18 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 18 | keningau
# Processing Record 37 of Set 18 | pontes e lacerda
# Processing Record 38 of Set 18 | lumeje
# Processing Record 39 of Set 18 | santa rosa
# Processing Record 40 of Set 18 | bolshoy kamen
# Processing Record 41 of Set 18 | popondetta
# Processing Record 42 of Set 18 | ginir
# Processing Record 43 of Set 18 | tuyen quang
# Processing Record 44 of Set 18 | kalemie
# Processing Record 45 of Set 18 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 18 | chernoyerkovskaya
# Processing Record 47 of Set 18 | ishigaki
# Processing Record 48 of Set 18 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 18 | platonovka
# Processing Record 50 of Set 18 | siniscola
# Processing Record 1 of Set 19 | lyngseidet
# Processing Record 2 of Set 19 | konya
# Processing Record 3 of Set 19 | zhigansk
# Processing Record 4 of Set 19 | phek
# Processing Record 5 of Set 19 | rawicz
# Processing Record 6 of Set 19 | point pedro
# Processing Record 7 of Set 19 | stokmarknes
# Processing Record 8 of Set 19 | fereydunshahr
# Processing Record 9 of Set 19 | sovetskiy
# Processing Record 10 of Set 19 | marovoay
# Processing Record 11 of Set 19 | praia da vitoria
# Processing Record 12 of Set 19 | winnemucca
# Processing Record 13 of Set 19 | mgachi
# Processing Record 14 of Set 19 | havre-saint-pierre
# Processing Record 15 of Set 19 | turukhansk
# Processing Record 16 of Set 19 | hradec kralove
# Processing Record 17 of Set 19 | luebo
# Processing Record 18 of Set 19 | upington
# Processing Record 19 of Set 19 | atar
# Processing Record 20 of Set 19 | richards bay
# Processing Record 21 of Set 19 | bolama
# Processing Record 22 of Set 19 | kindersley
# Processing Record 23 of Set 19 | comodoro rivadavia
# Processing Record 24 of Set 19 | melita
# Processing Record 25 of Set 19 | nishihara
# Processing Record 26 of Set 19 | starosubkhangulovo
# Processing Record 27 of Set 19 | qandala
# Processing Record 28 of Set 19 | mbandaka
# Processing Record 29 of Set 19 | plouzane
# Processing Record 30 of Set 19 | bababe
# City not found. Skipping...
# Processing Record 31 of Set 19 | saurimo
# Processing Record 32 of Set 19 | henties bay
# Processing Record 33 of Set 19 | asyut
# Processing Record 34 of Set 19 | dongsheng
# Processing Record 35 of Set 19 | kabale
# Processing Record 36 of Set 19 | lao cai
# Processing Record 37 of Set 19 | majene
# Processing Record 38 of Set 19 | batouri
# Processing Record 39 of Set 19 | husavik
# Processing Record 40 of Set 19 | mangrol
# Processing Record 41 of Set 19 | aligudarz
# Processing Record 42 of Set 19 | veraval
# Processing Record 43 of Set 19 | la tuque
# Processing Record 44 of Set 19 | isiro
# Processing Record 45 of Set 19 | baturaja
# Processing Record 46 of Set 19 | weihai
# Processing Record 47 of Set 19 | nueva gerona
# Processing Record 48 of Set 19 | livingston
# Processing Record 49 of Set 19 | lircay
# Processing Record 50 of Set 19 | port macquarie
# Processing Record 1 of Set 20 | papasquiaro
# City not found. Skipping...
# Processing Record 2 of Set 20 | solano
# Processing Record 3 of Set 20 | nelidovo
# Processing Record 4 of Set 20 | paita
# Processing Record 5 of Set 20 | maykain
# City not found. Skipping...
# Processing Record 6 of Set 20 | worland
# Processing Record 7 of Set 20 | whitley bay
# Processing Record 8 of Set 20 | zaysan
# Processing Record 9 of Set 20 | igarka
# Processing Record 10 of Set 20 | linjiang
# Processing Record 11 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 20 | labrea
# Processing Record 13 of Set 20 | subaytilah
# City not found. Skipping...
# Processing Record 14 of Set 20 | sao desiderio
# Processing Record 15 of Set 20 | tocopilla
# Processing Record 16 of Set 20 | oskemen
# Processing Record 17 of Set 20 | pathein
# Processing Record 18 of Set 20 | kitui
# Processing Record 19 of Set 20 | alugan
# Processing Record 20 of Set 20 | mawlaik
# Processing Record 21 of Set 20 | saint-donat-de-montcalm
# Processing Record 22 of Set 20 | dekar
# Processing Record 23 of Set 20 | goderich
# Processing Record 24 of Set 20 | achisay
# City not found. Skipping...
# Processing Record 25 of Set 20 | beinamar
# Processing Record 26 of Set 20 | ouadda
# Processing Record 27 of Set 20 | boguchany
# Processing Record 28 of Set 20 | manggar
# Processing Record 29 of Set 20 | lowestoft
# Processing Record 30 of Set 20 | hirara
# Processing Record 31 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 20 | paralimni
# Processing Record 33 of Set 20 | teguldet
# Processing Record 34 of Set 20 | okato
# Processing Record 35 of Set 20 | narasapur
# Processing Record 36 of Set 20 | tautira
# Processing Record 37 of Set 20 | gamba
# Processing Record 38 of Set 20 | palmas bellas
# Processing Record 39 of Set 20 | bethanien
# Processing Record 40 of Set 20 | mangan
# Processing Record 41 of Set 20 | benjamin aceval
# Processing Record 42 of Set 20 | ardatov
# Processing Record 43 of Set 20 | cedral
# Processing Record 44 of Set 20 | hollola
# Processing Record 45 of Set 20 | mana
# Processing Record 46 of Set 20 | camopi
# Processing Record 47 of Set 20 | solnechnyy
# Processing Record 48 of Set 20 | cacapava do sul
# Processing Record 49 of Set 20 | neiafu
# Processing Record 50 of Set 20 | paamiut
# Processing Record 1 of Set 21 | stournaraiika
# City not found. Skipping...
# Processing Record 2 of Set 21 | shellbrook
# Processing Record 3 of Set 21 | sosnovo-ozerskoye
# Processing Record 4 of Set 21 | chegdomyn
# Processing Record 5 of Set 21 | methoni
# Processing Record 6 of Set 21 | bichura
# Processing Record 7 of Set 21 | bereda
# Processing Record 8 of Set 21 | adelaide
# Processing Record 9 of Set 21 | mosetse
# Processing Record 10 of Set 21 | berezniki
# Processing Record 11 of Set 21 | cape coast
# Processing Record 12 of Set 21 | machico
# Processing Record 13 of Set 21 | novopokrovka
# Processing Record 14 of Set 21 | reconquista
# Processing Record 15 of Set 21 | carnduff
# Processing Record 16 of Set 21 | pangkalanbuun
# Processing Record 17 of Set 21 | aasiaat
# Processing Record 18 of Set 21 | barhi
# Processing Record 19 of Set 21 | puri
# Processing Record 20 of Set 21 | la union
# Processing Record 21 of Set 21 | kudahuvadhoo
# Processing Record 22 of Set 21 | tonneins
# Processing Record 23 of Set 21 | ambodifototra
# City not found. Skipping...
# Processing Record 24 of Set 21 | agadir
# Processing Record 25 of Set 21 | kautokeino
# Processing Record 26 of Set 21 | arak
# Processing Record 27 of Set 21 | illela
# Processing Record 28 of Set 21 | qurayyat
# Processing Record 29 of Set 21 | kefamenanu
# Processing Record 30 of Set 21 | teahupoo
# Processing Record 31 of Set 21 | jalu
# Processing Record 32 of Set 21 | razole
# Processing Record 33 of Set 21 | galle
# Processing Record 34 of Set 21 | quebec
# Processing Record 35 of Set 21 | moosomin
# Processing Record 36 of Set 21 | nago
# Processing Record 37 of Set 21 | santo antonio do leverger
# Processing Record 38 of Set 21 | ler
# Processing Record 39 of Set 21 | ahtopol
# Processing Record 40 of Set 21 | boden
# Processing Record 41 of Set 21 | umm kaddadah
# Processing Record 42 of Set 21 | khorixas
# Processing Record 43 of Set 21 | pocone
# Processing Record 44 of Set 21 | la libertad
# Processing Record 45 of Set 21 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 21 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 21 | alexandria
# Processing Record 48 of Set 21 | panguna
# Processing Record 49 of Set 21 | cohoes
# Processing Record 50 of Set 21 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 22 | morondava
# Processing Record 2 of Set 22 | pachino
# Processing Record 3 of Set 22 | chany
# Processing Record 4 of Set 22 | semey
# Processing Record 5 of Set 22 | marsabit
# Processing Record 6 of Set 22 | gorkovskoye
# City not found. Skipping...
# Processing Record 7 of Set 22 | port moresby
# Processing Record 8 of Set 22 | leh
# Processing Record 9 of Set 22 | asilah
# Processing Record 10 of Set 22 | yazykovo
# Processing Record 11 of Set 22 | najran
# Processing Record 12 of Set 22 | virden
# Processing Record 13 of Set 22 | lac du bonnet
# Processing Record 14 of Set 22 | chulman
# Processing Record 15 of Set 22 | hibbing
# Processing Record 16 of Set 22 | pandan
# Processing Record 17 of Set 22 | hit
# Processing Record 18 of Set 22 | sao pedro do sul
# Processing Record 19 of Set 22 | lhokseumawe
# Processing Record 20 of Set 22 | mosquera
# Processing Record 21 of Set 22 | batticaloa
# Processing Record 22 of Set 22 | malindi
# Processing Record 23 of Set 22 | yazman
# Processing Record 24 of Set 22 | phoenixville
# Processing Record 25 of Set 22 | buckeye
# Processing Record 26 of Set 22 | abu kamal
# Processing Record 27 of Set 22 | borisoglebsk
# Processing Record 28 of Set 22 | zimandu nou
# Processing Record 29 of Set 22 | nexo
# Processing Record 30 of Set 22 | yanam
# Processing Record 31 of Set 22 | sakakah
# Processing Record 32 of Set 22 | severnyy
# Processing Record 33 of Set 22 | bayir
# Processing Record 34 of Set 22 | afsin
# Processing Record 35 of Set 22 | nyzhni sirohozy
# Processing Record 36 of Set 22 | sivaki
# Processing Record 37 of Set 22 | taoudenni
# Processing Record 38 of Set 22 | borshchiv
# Processing Record 39 of Set 22 | bireun
# Processing Record 40 of Set 22 | manuk mangkaw
# ...
# Processing Record 1 of Set 40 | diapaga
# Processing Record 2 of Set 40 | praya
# Processing Record 3 of Set 40 | danville
# Processing Record 4 of Set 40 | gwanda
# Processing Record 5 of Set 40 | dnestrovsc
# Processing Record 6 of Set 40 | huancavelica
# Processing Record 7 of Set 40 | kangaatsiaq
# Processing Record 8 of Set 40 | clonakilty
# Processing Record 9 of Set 40 | moba
# Processing Record 10 of Set 40 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 40 | craig
# Processing Record 12 of Set 40 | igra
# Processing Record 13 of Set 40 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 40 | jujuy
# City not found. Skipping...
# Processing Record 15 of Set 40 | korbach
# Processing Record 16 of Set 40 | woodstock
# Processing Record 17 of Set 40 | vermillion
# Processing Record 18 of Set 40 | innisfail
# Processing Record 19 of Set 40 | laiagam
# City not found. Skipping...
# Processing Record 20 of Set 40 | norrtalje
# Processing Record 21 of Set 40 | hindaun
# Processing Record 22 of Set 40 | robertson
# Processing Record 23 of Set 40 | bundaberg
# Processing Record 24 of Set 40 | taonan
# Processing Record 25 of Set 40 | sofiysk
# City not found. Skipping...
# Processing Record 26 of Set 40 | claresholm
# Processing Record 27 of Set 40 | piacabucu
# Processing Record 28 of Set 40 | gelibolu
# Processing Record 29 of Set 40 | jaisalmer
# Processing Record 30 of Set 40 | formoso do araguaia
# City not found. Skipping...
# Processing Record 31 of Set 40 | fukue
# Processing Record 32 of Set 40 | beatrice
# Processing Record 33 of Set 40 | mimongo
# Processing Record 34 of Set 40 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 40 | pochutla
# Processing Record 36 of Set 40 | rabo de peixe
# Processing Record 37 of Set 40 | fomboni
# Processing Record 38 of Set 40 | nhamunda
# Processing Record 39 of Set 40 | gharghoda
# Processing Record 40 of Set 40 | bose
# Processing Record 41 of Set 40 | warah
# Processing Record 42 of Set 40 | binga
# Processing Record 43 of Set 40 | burns lake
# Processing Record 44 of Set 40 | lanzhou
# Processing Record 45 of Set 40 | grenaa
# Processing Record 46 of Set 40 | uglovka
# Processing Record 47 of Set 40 | dandong
# Processing Record 48 of Set 40 | chikmagalur
# Processing Record 49 of Set 40 | ilebo
# Processing Record 50 of Set 40 | oriximina
# Processing Record 1 of Set 41 | koppang
# Processing Record 2 of Set 41 | barentu
# Processing Record 3 of Set 41 | uvelskiy
# Processing Record 4 of Set 41 | drayton valley
# Processing Record 5 of Set 41 | mujiayingzi
# Processing Record 6 of Set 41 | nha trang
# Processing Record 7 of Set 41 | palmas
# Processing Record 8 of Set 41 | uaua
# Processing Record 9 of Set 41 | san ignacio
# Processing Record 10 of Set 41 | kosh-agach
# Processing Record 11 of Set 41 | natalinsk
# Processing Record 12 of Set 41 | malamig
# Processing Record 13 of Set 41 | tugulym
# Processing Record 14 of Set 41 | hoquiam
# Processing Record 15 of Set 41 | kentau
# Processing Record 16 of Set 41 | mbaiki
# Processing Record 17 of Set 41 | oparino
# Processing Record 18 of Set 41 | ijui
# Processing Record 19 of Set 41 | moscow
# Processing Record 20 of Set 41 | hun
# Processing Record 21 of Set 41 | rio negro
# Processing Record 22 of Set 41 | bagdarin
# Processing Record 23 of Set 41 | balimo
# City not found. Skipping...
# Processing Record 24 of Set 41 | sretensk
# Processing Record 25 of Set 41 | zolotukhino
# Processing Record 26 of Set 41 | dawei
# Processing Record 27 of Set 41 | lusambo
# Processing Record 28 of Set 41 | lloydminster
# Processing Record 29 of Set 41 | isoka
# Processing Record 30 of Set 41 | kidal
# Processing Record 31 of Set 41 | las vegas
# Processing Record 32 of Set 41 | berdigestyakh
# Processing Record 33 of Set 41 | lalomanu
# City not found. Skipping...
# Processing Record 34 of Set 41 | joinville
# Processing Record 35 of Set 41 | ronchi dei legionari
# Processing Record 36 of Set 41 | tromso
# Processing Record 37 of Set 41 | aksu
# Processing Record 38 of Set 41 | tubuala
# Processing Record 39 of Set 41 | ziway
# Processing Record 40 of Set 41 | charters towers
# Processing Record 41 of Set 41 | horadiz
# Processing Record 42 of Set 41 | kawalu
# Processing Record 43 of Set 41 | shamgarh
# Processing Record 44 of Set 41 | lazurne
# Processing Record 45 of Set 41 | kadoma
# Processing Record 46 of Set 41 | kuybysheve
# Processing Record 47 of Set 41 | biltine
# Processing Record 48 of Set 41 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 41 | kolobrzeg
# Processing Record 50 of Set 41 | tadine
# Processing Record 1 of Set 42 | charcas
# Processing Record 2 of Set 42 | maltahohe
# Processing Record 3 of Set 42 | bodinayakkanur
# Processing Record 4 of Set 42 | kamaishi
# Processing Record 5 of Set 42 | boksitogorsk
# Processing Record 6 of Set 42 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 42 | xinmin
# Processing Record 8 of Set 42 | abancay
# Processing Record 9 of Set 42 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 42 | glenwood springs
# Processing Record 11 of Set 42 | sorrento
# Processing Record 12 of Set 42 | kasongo-lunda
# Processing Record 13 of Set 42 | phalaborwa
# Processing Record 14 of Set 42 | lebanon
# Processing Record 15 of Set 42 | haapiti
# Processing Record 16 of Set 42 | mazagao
# Processing Record 17 of Set 42 | nenagh
# Processing Record 18 of Set 42 | dzaoudzi
# Processing Record 19 of Set 42 | krasnaya polyana
# Processing Record 20 of Set 42 | yakima
# Processing Record 21 of Set 42 | kachiry
# Processing Record 22 of Set 42 | neya
# Processing Record 23 of Set 42 | santo angelo
# Processing Record 24 of Set 42 | dongfeng
# Processing Record 25 of Set 42 | royal tunbridge wells
# Processing Record 26 of Set 42 | baglan
# Processing Record 27 of Set 42 | don sak
# Processing Record 28 of Set 42 | zastron
# Processing Record 29 of Set 42 | amga
# Processing Record 30 of Set 42 | college place
# Processing Record 31 of Set 42 | chaman
# Processing Record 32 of Set 42 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 42 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 42 | ostersund
# Processing Record 35 of Set 42 | son la
# Processing Record 36 of Set 42 | ialibu
# Processing Record 37 of Set 42 | pokrovsk
# Processing Record 38 of Set 42 | minchinabad
# Processing Record 39 of Set 42 | amahai
# Processing Record 40 of Set 42 | peremyshl
# Processing Record 41 of Set 42 | xuanhua
# Processing Record 42 of Set 42 | erenhot
# Processing Record 43 of Set 42 | aguas formosas
# Processing Record 44 of Set 42 | shirokaya rechka
# Processing Record 45 of Set 42 | beyla
# Processing Record 46 of Set 42 | tahta
# Processing Record 47 of Set 42 | santa fe
# Processing Record 48 of Set 42 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 49 of Set 42 | laguna de perlas
# Processing Record 50 of Set 42 | bongandanga
# Processing Record 1 of Set 43 | kyshtovka
# Processing Record 2 of Set 43 | homer
# Processing Record 3 of Set 43 | banjar
# Processing Record 4 of Set 43 | foz
# Processing Record 5 of Set 43 | killybegs
# Processing Record 6 of Set 43 | hushitai
# Processing Record 7 of Set 43 | kjollefjord
# Processing Record 8 of Set 43 | sokoni
# Processing Record 9 of Set 43 | mulchen
# Processing Record 10 of Set 43 | nizhniy mamon
# Processing Record 11 of Set 43 | horodok
# Processing Record 12 of Set 43 | santa ana
# Processing Record 13 of Set 43 | palasbari
# Processing Record 14 of Set 43 | orange
# Processing Record 15 of Set 43 | santarem
# Processing Record 16 of Set 43 | krusevac
# Processing Record 17 of Set 43 | kalmar
# Processing Record 18 of Set 43 | madison
# Processing Record 19 of Set 43 | gimli
# Processing Record 20 of Set 43 | tulca
# Processing Record 21 of Set 43 | kuusamo
# Processing Record 22 of Set 43 | senlis
# Processing Record 23 of Set 43 | kars
# Processing Record 24 of Set 43 | pervomayskiy
# Processing Record 25 of Set 43 | andenes
# Processing Record 26 of Set 43 | mocsa
# Processing Record 27 of Set 43 | sungaipenuh
# Processing Record 28 of Set 43 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 43 | luangwa
# Processing Record 30 of Set 43 | zelezny brod
# Processing Record 31 of Set 43 | nong chik
# Processing Record 32 of Set 43 | mizan teferi
# Processing Record 33 of Set 43 | cantagalo
# Processing Record 34 of Set 43 | raduzhnyy
# Processing Record 35 of Set 43 | russellville
# Processing Record 36 of Set 43 | clarksburg
# Processing Record 37 of Set 43 | waverley
# Processing Record 38 of Set 43 | arona
# Processing Record 39 of Set 43 | dejen
# Processing Record 40 of Set 43 | khartoum
# Processing Record 41 of Set 43 | zambezi
# Processing Record 42 of Set 43 | tananger
# Processing Record 43 of Set 43 | shitanjing
# Processing Record 44 of Set 43 | gidam
# Processing Record 45 of Set 43 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 43 | nieuw amsterdam
# Processing Record 47 of Set 43 | tucupita
# Processing Record 48 of Set 43 | paithan
# Processing Record 49 of Set 43 | fort morgan
# Processing Record 50 of Set 43 | jishou
# Processing Record 1 of Set 44 | nizhneangarsk
# Processing Record 2 of Set 44 | gao
# Processing Record 3 of Set 44 | huajuapan
# City not found. Skipping...
# Processing Record 4 of Set 44 | jaque
# Processing Record 5 of Set 44 | kracheh
# City not found. Skipping...
# Processing Record 6 of Set 44 | healdsburg
# Processing Record 7 of Set 44 | malanje
# Processing Record 8 of Set 44 | piranhas
# Processing Record 9 of Set 44 | kailua
# Processing Record 10 of Set 44 | tornio
# Processing Record 11 of Set 44 | tevaitoa
# Processing Record 12 of Set 44 | moranbah
# Processing Record 13 of Set 44 | taywarah
# Processing Record 14 of Set 44 | vasterhaninge
# Processing Record 15 of Set 44 | bosilegrad
# Processing Record 16 of Set 44 | toktogul
# Processing Record 17 of Set 44 | san matias
# Processing Record 18 of Set 44 | yamada
# Processing Record 19 of Set 44 | warrnambool
# Processing Record 20 of Set 44 | santiago
# Processing Record 21 of Set 44 | bretigny-sur-orge
# Processing Record 22 of Set 44 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 44 | balaipungut
# Processing Record 24 of Set 44 | monywa
# Processing Record 25 of Set 44 | kamen-rybolov
# Processing Record 26 of Set 44 | fenelon falls
# Processing Record 27 of Set 44 | humberto de campos
# Processing Record 28 of Set 44 | the valley
# Processing Record 29 of Set 44 | shubarkuduk
# Processing Record 30 of Set 44 | xam nua
# Processing Record 31 of Set 44 | winona
# Processing Record 32 of Set 44 | girne
# Processing Record 33 of Set 44 | russkiy aktash
# Processing Record 34 of Set 44 | delitzsch
# Processing Record 35 of Set 44 | maxixe
# Processing Record 36 of Set 44 | gushikawa
# Processing Record 37 of Set 44 | cururupu
# Processing Record 38 of Set 44 | borba
# Processing Record 39 of Set 44 | nayoro
# Processing Record 40 of Set 44 | rurrenabaque
# Processing Record 41 of Set 44 | phan thiet
# Processing Record 42 of Set 44 | cortes
# Processing Record 43 of Set 44 | lovington
# Processing Record 44 of Set 44 | demyansk
# Processing Record 45 of Set 44 | linden
# Processing Record 46 of Set 44 | yueyang
# Processing Record 47 of Set 44 | placerville
# Processing Record 48 of Set 44 | surt
# Processing Record 49 of Set 44 | belaya kholunitsa
# Processing Record 50 of Set 44 | susaki
# Processing Record 1 of Set 45 | srandakan
# Processing Record 2 of Set 45 | bacolod
# Processing Record 3 of Set 45 | candelaria
# Processing Record 4 of Set 45 | adiake
# Processing Record 5 of Set 45 | melbu
# Processing Record 6 of Set 45 | englewood
# Processing Record 7 of Set 45 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 45 | lanskroun
# Processing Record 9 of Set 45 | itambe
# Processing Record 10 of Set 45 | togitsu
# Processing Record 11 of Set 45 | tongling
# Processing Record 12 of Set 45 | tingrela
# City not found. Skipping...
# Processing Record 13 of Set 45 | rongcheng
# Processing Record 14 of Set 45 | gainesville
# Processing Record 15 of Set 45 | pascagoula
# Processing Record 16 of Set 45 | lensk
# Processing Record 17 of Set 45 | rudnogorsk
# Processing Record 18 of Set 45 | bjorkelangen
# Processing Record 19 of Set 45 | biskamzha
# Processing Record 20 of Set 45 | plymouth
# Processing Record 21 of Set 45 | yablonovo
# Processing Record 22 of Set 45 | kathua
# Processing Record 23 of Set 45 | farafangana
# Processing Record 24 of Set 45 | barra patuca
# Processing Record 25 of Set 45 | yankton
# Processing Record 26 of Set 45 | jinxiang
# Processing Record 27 of Set 45 | basco
# Processing Record 28 of Set 45 | inyonga
# Processing Record 29 of Set 45 | khashuri
# Processing Record 30 of Set 45 | plotnikovo
# Processing Record 31 of Set 45 | martinez
# Processing Record 32 of Set 45 | severobaykalsk
# Processing Record 33 of Set 45 | beidao
# Processing Record 34 of Set 45 | birao
# Processing Record 35 of Set 45 | tezu
# Processing Record 36 of Set 45 | belyy yar
# Processing Record 37 of Set 45 | dingtao
# Processing Record 38 of Set 45 | nancha
# Processing Record 39 of Set 45 | sibut
# Processing Record 40 of Set 45 | sfantu gheorghe
# Processing Record 41 of Set 45 | urdoma
# Processing Record 42 of Set 45 | yinchuan
# Processing Record 43 of Set 45 | la macarena
# Processing Record 44 of Set 45 | yarada
# Processing Record 45 of Set 45 | ayr
# Processing Record 46 of Set 45 | dinard
# Processing Record 47 of Set 45 | paka
# Processing Record 48 of Set 45 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 45 | alekseyevsk
# Processing Record 50 of Set 45 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 46 | palmerston
# Processing Record 2 of Set 46 | carlos chagas
# Processing Record 3 of Set 46 | talara
# Processing Record 4 of Set 46 | ilhabela
# Processing Record 5 of Set 46 | mitchell
# Processing Record 6 of Set 46 | calvinia
# Processing Record 7 of Set 46 | vedaranniyam
# City not found. Skipping...
# Processing Record 8 of Set 46 | dubti
# Processing Record 9 of Set 46 | tymovskoye
# Processing Record 10 of Set 46 | blythe
# Processing Record 11 of Set 46 | tabuk
# Processing Record 12 of Set 46 | bijar
# Processing Record 13 of Set 46 | mossendjo
# Processing Record 14 of Set 46 | khasan
# Processing Record 15 of Set 46 | yabelo
# Processing Record 16 of Set 46 | smithers
# Processing Record 17 of Set 46 | marand
# Processing Record 18 of Set 46 | micomeseng
# Processing Record 19 of Set 46 | yenangyaung
# Processing Record 20 of Set 46 | glendive
# Processing Record 21 of Set 46 | la possession
# Processing Record 22 of Set 46 | arti
# Processing Record 23 of Set 46 | bang saphan
# Processing Record 24 of Set 46 | baculin
# Processing Record 25 of Set 46 | collecchio
# Processing Record 26 of Set 46 | donji komren
# City not found. Skipping...
# Processing Record 27 of Set 46 | porto de moz
# Processing Record 28 of Set 46 | nalut
# Processing Record 29 of Set 46 | guajara-mirim
# City not found. Skipping...
# Processing Record 30 of Set 46 | vera cruz
# Processing Record 31 of Set 46 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 46 | zaoyang
# Processing Record 33 of Set 46 | fougamou
# Processing Record 34 of Set 46 | sangolqui
# Processing Record 35 of Set 46 | imamoglu
# Processing Record 36 of Set 46 | ajdabiya
# Processing Record 37 of Set 46 | troitsk
# Processing Record 38 of Set 46 | peleduy
# Processing Record 39 of Set 46 | rawlins
# Processing Record 40 of Set 46 | ati
# Processing Record 41 of Set 46 | beihai
# Processing Record 42 of Set 46 | simeykyne
# Processing Record 43 of Set 46 | apache junction
# Processing Record 44 of Set 46 | general roca
# Processing Record 45 of Set 46 | banikoara
# Processing Record 46 of Set 46 | sonkovo
# Processing Record 47 of Set 46 | tvoroyri
# Processing Record 48 of Set 46 | cootamundra
# Processing Record 49 of Set 46 | gonen
# Processing Record 50 of Set 46 | taft
# Processing Record 1 of Set 47 | vite
# Processing Record 2 of Set 47 | tamarindo
# Processing Record 3 of Set 47 | bad sankt leonhard
# City not found. Skipping...
# Processing Record 4 of Set 47 | manaus
# Processing Record 5 of Set 47 | bam
# Processing Record 6 of Set 47 | akureyri
# Processing Record 7 of Set 47 | kalamazoo
# Processing Record 8 of Set 47 | rapar
# Processing Record 9 of Set 47 | mucuri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Ostrovnoy  68.0531   39.5131     32.94        71           7       11.97
# 1     Dikson  73.5069   80.5464     28.06        96         100       10.33
# 2     Albany  42.6001  -73.9662     88.92        58          42        1.99
# 3   Qaqortoq  60.7167  -46.0333     37.87        95         100       16.62
# 4       Hilo  19.7297 -155.0900     72.28        88           0        7.00
# 5    Belebey  54.1167   54.1167     41.86        84          87        2.73
# 6    Ushuaia -54.8000  -68.3000     37.06        93          20        2.30
# 7     Hasaki  35.7333  140.8333     61.29        81          97        8.86
# 8    Rikitea -23.1203 -134.9692     75.96        76           8       13.29
# 9  Galveston  29.3669  -94.9669     80.56        74           0       16.11
#
#   Country Current Conditions
# 0      RU          clear sky
# 1      RU         light snow
# 2      US   scattered clouds
# 3      GL      moderate rain
# 4      US          clear sky
# 5      RU    overcast clouds
# 6      AR         few clouds
# 7      JP    overcast clouds
# 8      PF          clear sky
# 9      US          clear sky

# %%
# Reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Conditions"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ostrovnoy      RU  68.0531   39.5131     32.94        71           7
# 1     Dikson      RU  73.5069   80.5464     28.06        96         100
# 2     Albany      US  42.6001  -73.9662     88.92        58          42
# 3   Qaqortoq      GL  60.7167  -46.0333     37.87        95         100
# 4       Hilo      US  19.7297 -155.0900     72.28        88           0
# 5    Belebey      RU  54.1167   54.1167     41.86        84          87
# 6    Ushuaia      AR -54.8000  -68.3000     37.06        93          20
# 7     Hasaki      JP  35.7333  140.8333     61.29        81          97
# 8    Rikitea      PF -23.1203 -134.9692     75.96        76           8
# 9  Galveston      US  29.3669  -94.9669     80.56        74           0
#
#    Wind Speed Current Conditions
# 0       11.97          clear sky
# 1       10.33         light snow
# 2        1.99   scattered clouds
# 3       16.62      moderate rain
# 4        7.00          clear sky
# 5        2.73    overcast clouds
# 6        2.30         few clouds
# 7        8.86    overcast clouds
# 8       13.29          clear sky
# 9       16.11          clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
