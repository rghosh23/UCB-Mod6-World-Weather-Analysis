# %%
# 1a. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 615

# %%
# 1b. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 2. Loop through the cities list.
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # 4. Build the city_url or endpoint for each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # 5. Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# 6. Make an API request for each city.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | gelemso
# Processing Record 2 of Set 1 | fornosovo
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | billings
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | shetpe
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | lavrentiya
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | hovd
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | san juan
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | leningradskiy
# Processing Record 24 of Set 1 | hammerfest
# Processing Record 25 of Set 1 | mount isa
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | krasnoborsk
# Processing Record 29 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | paraopeba
# Processing Record 33 of Set 1 | nalut
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | ouesso
# Processing Record 36 of Set 1 | northam
# Processing Record 37 of Set 1 | sahuaripa
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | yuma
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | bowen
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | kovur
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | sept-iles
# Processing Record 49 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | korcula
# Processing Record 3 of Set 2 | iskele
# Processing Record 4 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 2 | vardo
# Processing Record 6 of Set 2 | dunedin
# Processing Record 7 of Set 2 | presidencia roque saenz pena
# Processing Record 8 of Set 2 | logan
# Processing Record 9 of Set 2 | neryungri
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | ramgarh
# Processing Record 13 of Set 2 | karwar
# Processing Record 14 of Set 2 | lompoc
# Processing Record 15 of Set 2 | san cristobal
# Processing Record 16 of Set 2 | san andres
# Processing Record 17 of Set 2 | luorong
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 20 of Set 2 | kachikau
# City not found. Skipping...
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | anloga
# Processing Record 25 of Set 2 | aklavik
# Processing Record 26 of Set 2 | kayerkan
# Processing Record 27 of Set 2 | maniwaki
# Processing Record 28 of Set 2 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 29 of Set 2 | sulangan
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | bilma
# Processing Record 32 of Set 2 | kraliky
# Processing Record 33 of Set 2 | el cope
# Processing Record 34 of Set 2 | laguna
# Processing Record 35 of Set 2 | alofi
# Processing Record 36 of Set 2 | zemio
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | mandalgovi
# Processing Record 40 of Set 2 | mata
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | udomlya
# Processing Record 43 of Set 2 | corralillo
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | kimberley
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | antanifotsy
# Processing Record 1 of Set 3 | sorland
# Processing Record 2 of Set 3 | rikitea
# Processing Record 3 of Set 3 | bilibino
# Processing Record 4 of Set 3 | narrabri
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | new norfolk
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | oistins
# Processing Record 14 of Set 3 | feltre
# Processing Record 15 of Set 3 | camana
# Processing Record 16 of Set 3 | forbes
# Processing Record 17 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 3 | ambon
# Processing Record 19 of Set 3 | ngunguru
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | cururupu
# Processing Record 22 of Set 3 | cape town
# Processing Record 23 of Set 3 | arcata
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | kavieng
# Processing Record 26 of Set 3 | olafsvik
# Processing Record 27 of Set 3 | kavaratti
# Processing Record 28 of Set 3 | rawson
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | mabaruma
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | broome
# Processing Record 35 of Set 3 | hami
# Processing Record 36 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 3 | panorama
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | fort saint james
# Processing Record 40 of Set 3 | vanavara
# Processing Record 41 of Set 3 | inta
# Processing Record 42 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 3 | channel-port aux basques
# Processing Record 44 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 3 | tacuarembo
# Processing Record 46 of Set 3 | hilo
# Processing Record 47 of Set 3 | tema
# Processing Record 48 of Set 3 | abu dhabi
# Processing Record 49 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 3 | koumac
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | yellowknife
# Processing Record 3 of Set 4 | rio gallegos
# Processing Record 4 of Set 4 | hwange
# Processing Record 5 of Set 4 | jizan
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | yarada
# Processing Record 8 of Set 4 | daraitan
# Processing Record 9 of Set 4 | sinnamary
# Processing Record 10 of Set 4 | qaanaaq
# Processing Record 11 of Set 4 | jamestown
# Processing Record 12 of Set 4 | okhotsk
# Processing Record 13 of Set 4 | ust-tsilma
# Processing Record 14 of Set 4 | raduzhnyy
# Processing Record 15 of Set 4 | brunswick
# Processing Record 16 of Set 4 | bambous virieux
# Processing Record 17 of Set 4 | sao joao da barra
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | cidreira
# Processing Record 20 of Set 4 | hay river
# Processing Record 21 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 4 | mezen
# Processing Record 23 of Set 4 | shuiji
# Processing Record 24 of Set 4 | meulaboh
# Processing Record 25 of Set 4 | herten
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | tautira
# Processing Record 28 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 4 | abu samrah
# Processing Record 30 of Set 4 | dormidontovka
# Processing Record 31 of Set 4 | pointe-noire
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | pacific grove
# Processing Record 34 of Set 4 | debre birhan
# Processing Record 35 of Set 4 | daru
# Processing Record 36 of Set 4 | sur
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | nevelsk
# Processing Record 39 of Set 4 | karratha
# Processing Record 40 of Set 4 | otane
# Processing Record 41 of Set 4 | dicabisagan
# Processing Record 42 of Set 4 | virginia beach
# Processing Record 43 of Set 4 | leh
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | acarau
# Processing Record 46 of Set 4 | zakamensk
# Processing Record 47 of Set 4 | marzuq
# Processing Record 48 of Set 4 | tiksi
# Processing Record 49 of Set 4 | nantucket
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 1 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 5 | petrovsk
# Processing Record 3 of Set 5 | celle
# Processing Record 4 of Set 5 | tabriz
# Processing Record 5 of Set 5 | praia
# Processing Record 6 of Set 5 | iracoubo
# Processing Record 7 of Set 5 | san joaquin
# Processing Record 8 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 5 | avarua
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 5 | dikson
# Processing Record 13 of Set 5 | port hedland
# Processing Record 14 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 5 | maria chiquita
# Processing Record 16 of Set 5 | yemanzhelinsk
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | buraydah
# Processing Record 19 of Set 5 | tessalit
# Processing Record 20 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 5 | grindavik
# Processing Record 22 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 23 of Set 5 | faya
# Processing Record 24 of Set 5 | conakry
# Processing Record 25 of Set 5 | zhigansk
# Processing Record 26 of Set 5 | baturaja
# Processing Record 27 of Set 5 | addis zemen
# City not found. Skipping...
# Processing Record 28 of Set 5 | kodinsk
# Processing Record 29 of Set 5 | moroni
# Processing Record 30 of Set 5 | fomboni
# Processing Record 31 of Set 5 | nyaunglebin
# Processing Record 32 of Set 5 | camacha
# Processing Record 33 of Set 5 | mayachnyy
# Processing Record 34 of Set 5 | inhambane
# Processing Record 35 of Set 5 | caravelas
# Processing Record 36 of Set 5 | taoudenni
# Processing Record 37 of Set 5 | benguela
# Processing Record 38 of Set 5 | lagos
# Processing Record 39 of Set 5 | pingliang
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | avera
# Processing Record 42 of Set 5 | hofn
# Processing Record 43 of Set 5 | hendrina
# Processing Record 44 of Set 5 | xining
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | luena
# Processing Record 47 of Set 5 | touros
# Processing Record 48 of Set 5 | itacare
# Processing Record 49 of Set 5 | salalah
# Processing Record 50 of Set 5 | kohat
# Processing Record 1 of Set 6 | zaysan
# Processing Record 2 of Set 6 | marawi
# Processing Record 3 of Set 6 | kahului
# Processing Record 4 of Set 6 | cockburn town
# Processing Record 5 of Set 6 | kushmurun
# Processing Record 6 of Set 6 | zaliztsi
# Processing Record 7 of Set 6 | talnakh
# Processing Record 8 of Set 6 | zhaotong
# Processing Record 9 of Set 6 | arlit
# Processing Record 10 of Set 6 | ierapetra
# Processing Record 11 of Set 6 | sao raimundo nonato
# Processing Record 12 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 6 | waingapu
# Processing Record 14 of Set 6 | palaikastron
# Processing Record 15 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 16 of Set 6 | dragoman
# Processing Record 17 of Set 6 | puerto madryn
# Processing Record 18 of Set 6 | nuuk
# Processing Record 19 of Set 6 | hambantota
# Processing Record 20 of Set 6 | longyearbyen
# Processing Record 21 of Set 6 | ulaanbaatar
# Processing Record 22 of Set 6 | shingu
# Processing Record 23 of Set 6 | puerto triunfo
# Processing Record 24 of Set 6 | peniche
# Processing Record 25 of Set 6 | otavi
# Processing Record 26 of Set 6 | sant julia de loria
# Processing Record 27 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 6 | kiruna
# Processing Record 29 of Set 6 | douglas
# Processing Record 30 of Set 6 | jiazi
# Processing Record 31 of Set 6 | rio grande
# Processing Record 32 of Set 6 | nagua
# Processing Record 33 of Set 6 | nazas
# Processing Record 34 of Set 6 | kosa
# Processing Record 35 of Set 6 | bulawayo
# Processing Record 36 of Set 6 | turayf
# Processing Record 37 of Set 6 | pangnirtung
# Processing Record 38 of Set 6 | awbari
# Processing Record 39 of Set 6 | sikea
# City not found. Skipping...
# Processing Record 40 of Set 6 | yumen
# Processing Record 41 of Set 6 | pastos bons
# Processing Record 42 of Set 6 | birao
# Processing Record 43 of Set 6 | batagay
# Processing Record 44 of Set 6 | machachi
# Processing Record 45 of Set 6 | filadelfia
# Processing Record 46 of Set 6 | na wa
# Processing Record 47 of Set 6 | lae
# Processing Record 48 of Set 6 | sao jose da coroa grande
# Processing Record 49 of Set 6 | opuwo
# Processing Record 50 of Set 6 | tezu
# Processing Record 1 of Set 7 | fevik
# Processing Record 2 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 7 | ankang
# Processing Record 4 of Set 7 | roswell
# Processing Record 5 of Set 7 | sorong
# Processing Record 6 of Set 7 | hualmay
# Processing Record 7 of Set 7 | yatou
# Processing Record 8 of Set 7 | saint-pierre
# Processing Record 9 of Set 7 | victoria point
# Processing Record 10 of Set 7 | kinston
# Processing Record 11 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 7 | puerto baquerizo moreno
# Processing Record 13 of Set 7 | lebu
# Processing Record 14 of Set 7 | carpentras
# Processing Record 15 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 7 | elk plain
# Processing Record 17 of Set 7 | novyy urengoy
# Processing Record 18 of Set 7 | namatanai
# Processing Record 19 of Set 7 | preobrazheniye
# Processing Record 20 of Set 7 | kismayo
# Processing Record 21 of Set 7 | jalu
# Processing Record 22 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 23 of Set 7 | santa maria
# Processing Record 24 of Set 7 | muros
# Processing Record 25 of Set 7 | haapiti
# Processing Record 26 of Set 7 | bathsheba
# Processing Record 27 of Set 7 | uppsala
# Processing Record 28 of Set 7 | biak
# Processing Record 29 of Set 7 | itarema
# Processing Record 30 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 31 of Set 7 | collipulli
# Processing Record 32 of Set 7 | loreto
# Processing Record 33 of Set 7 | gotsu
# Processing Record 34 of Set 7 | mackay
# Processing Record 35 of Set 7 | coihaique
# Processing Record 36 of Set 7 | fortuna
# Processing Record 37 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 7 | flinders
# Processing Record 39 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 7 | guiyang
# Processing Record 41 of Set 7 | yulara
# Processing Record 42 of Set 7 | ruteng
# Processing Record 43 of Set 7 | moerai
# Processing Record 44 of Set 7 | carutapera
# Processing Record 45 of Set 7 | guozhen
# Processing Record 46 of Set 7 | antofagasta
# Processing Record 47 of Set 7 | tiznit
# Processing Record 48 of Set 7 | nueva guinea
# Processing Record 49 of Set 7 | kununurra
# Processing Record 50 of Set 7 | te anau
# Processing Record 1 of Set 8 | boyolangu
# Processing Record 2 of Set 8 | torbay
# Processing Record 3 of Set 8 | srednekolymsk
# Processing Record 4 of Set 8 | san patricio
# Processing Record 5 of Set 8 | penzance
# Processing Record 6 of Set 8 | fort wellington
# Processing Record 7 of Set 8 | harrison
# Processing Record 8 of Set 8 | cherdyn
# Processing Record 9 of Set 8 | namibe
# Processing Record 10 of Set 8 | zhangjiakou
# Processing Record 11 of Set 8 | songjianghe
# Processing Record 12 of Set 8 | garcia
# Processing Record 13 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 8 | shimoda
# Processing Record 15 of Set 8 | ugoofaaru
# Processing Record 16 of Set 8 | kuching
# Processing Record 17 of Set 8 | terre haute
# Processing Record 18 of Set 8 | sri aman
# Processing Record 19 of Set 8 | cap malheureux
# Processing Record 20 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 8 | menongue
# Processing Record 22 of Set 8 | bakel
# Processing Record 23 of Set 8 | mandapam
# Processing Record 24 of Set 8 | naryan-mar
# Processing Record 25 of Set 8 | verkhnevilyuysk
# Processing Record 26 of Set 8 | hasaki
# Processing Record 27 of Set 8 | san quintin
# Processing Record 28 of Set 8 | pisco
# Processing Record 29 of Set 8 | vadso
# Processing Record 30 of Set 8 | evensk
# Processing Record 31 of Set 8 | valjala
# City not found. Skipping...
# Processing Record 32 of Set 8 | palmer
# Processing Record 33 of Set 8 | tandil
# Processing Record 34 of Set 8 | ucluelet
# Processing Record 35 of Set 8 | katherine
# Processing Record 36 of Set 8 | taonan
# Processing Record 37 of Set 8 | harper
# Processing Record 38 of Set 8 | severo-kurilsk
# Processing Record 39 of Set 8 | gao
# Processing Record 40 of Set 8 | okha
# Processing Record 41 of Set 8 | ambilobe
# Processing Record 42 of Set 8 | kemijarvi
# Processing Record 43 of Set 8 | nagato
# Processing Record 44 of Set 8 | airai
# Processing Record 45 of Set 8 | fort nelson
# Processing Record 46 of Set 8 | cochrane
# Processing Record 47 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 8 | marsh harbour
# Processing Record 49 of Set 8 | grand baie
# Processing Record 50 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 1 of Set 9 | urengoy
# Processing Record 2 of Set 9 | paamiut
# Processing Record 3 of Set 9 | emet
# Processing Record 4 of Set 9 | nautla
# Processing Record 5 of Set 9 | mount gambier
# Processing Record 6 of Set 9 | comodoro rivadavia
# Processing Record 7 of Set 9 | orumiyeh
# Processing Record 8 of Set 9 | honiara
# Processing Record 9 of Set 9 | kruisfontein
# Processing Record 10 of Set 9 | goiatuba
# Processing Record 11 of Set 9 | kraksaan
# Processing Record 12 of Set 9 | anaconda
# Processing Record 13 of Set 9 | east london
# Processing Record 14 of Set 9 | port pirie
# Processing Record 15 of Set 9 | labrea
# Processing Record 16 of Set 9 | ayagoz
# Processing Record 17 of Set 9 | pacifica
# Processing Record 18 of Set 9 | lagoa
# Processing Record 19 of Set 9 | piacabucu
# Processing Record 20 of Set 9 | fuerte olimpo
# Processing Record 21 of Set 9 | guajara-mirim
# City not found. Skipping...
# Processing Record 22 of Set 9 | beaufort
# Processing Record 23 of Set 9 | puerto pailas
# Processing Record 24 of Set 9 | port hardy
# Processing Record 25 of Set 9 | kabinda
# Processing Record 26 of Set 9 | eureka
# Processing Record 27 of Set 9 | caceres
# Processing Record 28 of Set 9 | caloundra
# Processing Record 29 of Set 9 | miandrivazo
# Processing Record 30 of Set 9 | zaplyusye
# City not found. Skipping...
# Processing Record 31 of Set 9 | veraval
# Processing Record 32 of Set 9 | tuatapere
# Processing Record 33 of Set 9 | sumbe
# Processing Record 34 of Set 9 | tasiilaq
# Processing Record 35 of Set 9 | san carlos de bariloche
# Processing Record 36 of Set 9 | lakes entrance
# Processing Record 37 of Set 9 | nkhotakota
# Processing Record 38 of Set 9 | ha giang
# Processing Record 39 of Set 9 | suffolk
# Processing Record 40 of Set 9 | lappeenranta
# Processing Record 41 of Set 9 | ongandjera
# Processing Record 42 of Set 9 | inirida
# Processing Record 43 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 9 | kuryk
# Processing Record 45 of Set 9 | maragogi
# Processing Record 46 of Set 9 | mathathane
# Processing Record 47 of Set 9 | omboue
# Processing Record 48 of Set 9 | udachnyy
# Processing Record 49 of Set 9 | iskateley
# Processing Record 50 of Set 9 | neuquen
# Processing Record 1 of Set 10 | springdale
# Processing Record 2 of Set 10 | treinta y tres
# Processing Record 3 of Set 10 | nhulunbuy
# Processing Record 4 of Set 10 | sitka
# Processing Record 5 of Set 10 | kedrovyy
# Processing Record 6 of Set 10 | tocache
# Processing Record 7 of Set 10 | dingle
# Processing Record 8 of Set 10 | west bend
# Processing Record 9 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 10 of Set 10 | salinopolis
# Processing Record 11 of Set 10 | ancud
# Processing Record 12 of Set 10 | malakal
# Processing Record 13 of Set 10 | eyl
# Processing Record 14 of Set 10 | murmashi
# Processing Record 15 of Set 10 | araouane
# Processing Record 16 of Set 10 | san vicente
# Processing Record 17 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set 10 | santiago de cao
# Processing Record 19 of Set 10 | solhan
# Processing Record 20 of Set 10 | pilar
# Processing Record 21 of Set 10 | morant bay
# Processing Record 22 of Set 10 | thanh hoa
# Processing Record 23 of Set 10 | diego de almagro
# Processing Record 24 of Set 10 | date
# Processing Record 25 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 26 of Set 10 | koungou
# Processing Record 27 of Set 10 | kirakira
# Processing Record 28 of Set 10 | wanning
# Processing Record 29 of Set 10 | baghmara
# Processing Record 30 of Set 10 | qaqortoq
# Processing Record 31 of Set 10 | alibag
# Processing Record 32 of Set 10 | klaksvik
# Processing Record 33 of Set 10 | las cruces
# Processing Record 34 of Set 10 | surt
# Processing Record 35 of Set 10 | challans
# Processing Record 36 of Set 10 | manaus
# Processing Record 37 of Set 10 | shahr-e kord
# Processing Record 38 of Set 10 | ilulissat
# Processing Record 39 of Set 10 | pecos
# Processing Record 40 of Set 10 | aswan
# Processing Record 41 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 10 | onega
# Processing Record 43 of Set 10 | magadi
# Processing Record 44 of Set 10 | margate
# Processing Record 45 of Set 10 | shadrinsk
# Processing Record 46 of Set 10 | tekeli
# Processing Record 47 of Set 10 | awjilah
# Processing Record 48 of Set 10 | baker city
# Processing Record 49 of Set 10 | khromtau
# Processing Record 50 of Set 10 | tarko-sale
# Processing Record 1 of Set 11 | imbituba
# Processing Record 2 of Set 11 | ulladulla
# Processing Record 3 of Set 11 | bubaque
# Processing Record 4 of Set 11 | stonewall
# Processing Record 5 of Set 11 | mielec
# Processing Record 6 of Set 11 | jieshi
# Processing Record 7 of Set 11 | maceio
# Processing Record 8 of Set 11 | norman wells
# Processing Record 9 of Set 11 | cayenne
# Processing Record 10 of Set 11 | santo antonio do ica
# Processing Record 11 of Set 11 | padang
# Processing Record 12 of Set 11 | svetlyy
# Processing Record 13 of Set 11 | visby
# Processing Record 14 of Set 11 | vertientes
# Processing Record 15 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 11 | labuhan
# Processing Record 17 of Set 11 | starosubkhangulovo
# Processing Record 18 of Set 11 | berbera
# Processing Record 19 of Set 11 | mogadouro
# Processing Record 20 of Set 11 | hinatuan
# Processing Record 21 of Set 11 | gushikawa
# Processing Record 22 of Set 11 | hailar
# Processing Record 23 of Set 11 | laizhou
# Processing Record 24 of Set 11 | huarmey
# Processing Record 25 of Set 11 | phalombe
# Processing Record 26 of Set 11 | knysna
# Processing Record 27 of Set 11 | jiayuguan
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | bardiyah
# Processing Record 30 of Set 11 | kisanga
# Processing Record 31 of Set 11 | acapulco
# Processing Record 32 of Set 11 | ipswich
# Processing Record 33 of Set 11 | kenai
# Processing Record 34 of Set 11 | richards bay
# Processing Record 35 of Set 11 | peace river
# Processing Record 36 of Set 11 | grand gaube
# Processing Record 37 of Set 11 | kholtoson
# Processing Record 38 of Set 11 | hokitika
# Processing Record 39 of Set 11 | zlatarica
# City not found. Skipping...
# Processing Record 40 of Set 11 | kinshasa
# Processing Record 41 of Set 11 | bambanglipuro
# Processing Record 42 of Set 11 | beringovskiy
# Processing Record 43 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 11 | saurimo
# Processing Record 45 of Set 11 | banikoara
# Processing Record 46 of Set 11 | barcelona
# Processing Record 47 of Set 11 | tucurui
# Processing Record 48 of Set 11 | pula
# Processing Record 49 of Set 11 | quetta
# Processing Record 50 of Set 11 | kushiro
# Processing Record 1 of Set 12 | yerbogachen
# Processing Record 2 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 12 | batticaloa
# Processing Record 4 of Set 12 | ostersund
# Processing Record 5 of Set 12 | juneau
# Processing Record 6 of Set 12 | kabo
# Processing Record 7 of Set 12 | sabha
# Processing Record 8 of Set 12 | gulu
# Processing Record 9 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 12 | bom jesus
# Processing Record 11 of Set 12 | ilhabela
# Processing Record 12 of Set 12 | ventersburg
# Processing Record 13 of Set 12 | la ronge
# Processing Record 14 of Set 12 | college
# Processing Record 15 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 16 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 12 | burica
# City not found. Skipping...
# Processing Record 18 of Set 12 | dzerzhinskoye
# Processing Record 19 of Set 12 | husavik
# Processing Record 20 of Set 12 | waipawa
# Processing Record 21 of Set 12 | manta
# Processing Record 22 of Set 12 | dunapataj
# Processing Record 23 of Set 12 | tocopilla
# Processing Record 24 of Set 12 | gatton
# Processing Record 25 of Set 12 | blankenburg
# Processing Record 26 of Set 12 | adrar
# Processing Record 27 of Set 12 | mkushi
# Processing Record 28 of Set 12 | turka
# Processing Record 29 of Set 12 | tarakan
# Processing Record 30 of Set 12 | moroto
# Processing Record 31 of Set 12 | gaziantep
# Processing Record 32 of Set 12 | aykino
# Processing Record 33 of Set 12 | dickinson
# Processing Record 34 of Set 12 | thinadhoo
# Processing Record 35 of Set 12 | itamaraca
# Processing Record 36 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 12 | gornyak
# Processing Record 38 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 12 | kulu
# Processing Record 40 of Set 12 | umm lajj
# Processing Record 41 of Set 12 | khovu-aksy
# Processing Record 42 of Set 12 | haines junction
# Processing Record 43 of Set 12 | axim
# Processing Record 44 of Set 12 | quelimane
# Processing Record 45 of Set 12 | carauari
# Processing Record 46 of Set 12 | ajdabiya
# Processing Record 47 of Set 12 | akure
# Processing Record 48 of Set 12 | kribi
# Processing Record 49 of Set 12 | chitrakonda
# Processing Record 50 of Set 12 | vestmanna
# Processing Record 1 of Set 13 | vostok
# Processing Record 2 of Set 13 | campbell river
# Processing Record 3 of Set 13 | aitape
# Processing Record 4 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 13 | plaridel
# Processing Record 6 of Set 13 | sumbawanga
# Processing Record 7 of Set 13 | lasa
# Processing Record 8 of Set 13 | ferrol
# Processing Record 9 of Set 13 | asau
# Processing Record 10 of Set 13 | walvis bay
# Processing Record 11 of Set 13 | roma
# Processing Record 12 of Set 13 | bara
# Processing Record 13 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 13 | santo tomas
# Processing Record 15 of Set 13 | panguna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Parse the JSON weather data for the following: 
# a. City, country, and date
# b. Latitude and longitude
# c. Max Temp
# d. Humidity
# e. Cloudiness
# f. Wind Speed

# %%
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Gelemso   8.8167   40.5167     68.13        66          77
# 1     Fornosovo  59.5689   30.5544     46.63        51           0
# 2     Hithadhoo  -0.6000   73.0833     83.46        69         100
# 3      Billings  45.7833 -108.5007     44.37        54          75
# 4       Ushuaia -54.8000  -68.3000     37.06        81           0
# 5        Shetpe  44.1667   52.1167     64.67        49          43
# 6    Georgetown   5.4112  100.3354     87.75        74          40
# 7      Khatanga  71.9667  102.5000     36.21        86         100
# 8         Kapaa  22.0752 -159.3190     78.78        89          75
# 9  Puerto Ayora  -0.7393  -90.3518     71.08        89          56
#
#    Wind Speed Country                 Date
# 0        6.06      ET  2022-05-22 04:37:03
# 1        7.00      RU  2022-05-22 04:37:04
# 2       11.03      MV  2022-05-22 04:32:28
# 3        6.91      US  2022-05-22 04:37:04
# 4        3.44      AR  2022-05-22 04:32:49
# 5       23.49      KZ  2022-05-22 04:37:05
# 6        5.99      MY  2022-05-22 04:32:30
# 7        8.14      RU  2022-05-22 04:36:50
# 8       11.50      US  2022-05-22 04:31:11
# 9        5.82      EC  2022-05-22 04:31:02

# %%
# Reorder columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       Gelemso      ET  2022-05-22 04:37:03   8.8167   40.5167     68.13
# 1     Fornosovo      RU  2022-05-22 04:37:04  59.5689   30.5544     46.63
# 2     Hithadhoo      MV  2022-05-22 04:32:28  -0.6000   73.0833     83.46
# 3      Billings      US  2022-05-22 04:37:04  45.7833 -108.5007     44.37
# 4       Ushuaia      AR  2022-05-22 04:32:49 -54.8000  -68.3000     37.06
# 5        Shetpe      KZ  2022-05-22 04:37:05  44.1667   52.1167     64.67
# 6    Georgetown      MY  2022-05-22 04:32:30   5.4112  100.3354     87.75
# 7      Khatanga      RU  2022-05-22 04:36:50  71.9667  102.5000     36.21
# 8         Kapaa      US  2022-05-22 04:31:11  22.0752 -159.3190     78.78
# 9  Puerto Ayora      EC  2022-05-22 04:31:02  -0.7393  -90.3518     71.08
#
#    Humidity  Cloudiness  Wind Speed
# 0        66          77        6.06
# 1        51           0        7.00
# 2        69         100       11.03
# 3        54          75        6.91
# 4        81           0        3.44
# 5        49          43       23.49
# 6        74          40        5.99
# 7        86         100        8.14
# 8        89          75       11.50
# 9        89          56        5.82

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Data Plotting
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# hemisphere df creation practice
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0     Gelemso      ET  2022-05-22 04:37:03   8.8167   40.5167     68.13
# 1   Fornosovo      RU  2022-05-22 04:37:04  59.5689   30.5544     46.63
# 3    Billings      US  2022-05-22 04:37:04  45.7833 -108.5007     44.37
# 5      Shetpe      KZ  2022-05-22 04:37:05  44.1667   52.1167     64.67
# 6  Georgetown      MY  2022-05-22 04:32:30   5.4112  100.3354     87.75
#
#    Humidity  Cloudiness  Wind Speed
# 0        66          77        6.06
# 1        51           0        7.00
# 3        54          75        6.91
# 5        49          43       23.49
# 6        74          40        5.99

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Cloudiness', 'Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
